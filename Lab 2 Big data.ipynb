# %%
# import packages for analysis and modeling
import pandas as pd #data frame operations
import numpy as np #arrays and math functions
from scipy.stats import uniform #for training and test splits
import statsmodels.api as smf #R-like model specification
import matplotlib.pyplot as plt #2D plotting
import seaborn as sns #seaborn plots
from sklearn.linear_model import LinearRegression #linear regression package
from sklearn.metrics import r2_score 
from statsmodels.graphics.tsaplots import plot_acf #autoregressive plot
from statsmodels.graphics.tsaplots import plot_pacf #partial correlation plot
from statsmodels.tsa.stattools import adfuller #stationary test
from sklearn.model_selection import train_test_split #train and test split
import statsmodels.api as sm

# %%
import os
os.chdir('/users/tofaj/Downloads') #change directory to downloads to load csv
os.getcwd()
# Out:
# 'C:\\users\\tofaj\\Downloads'

# %%
zip_data = pd.read_csv('Zip_zhvi_uc_sfr_month.csv')
zipdf = pd.DataFrame(zip_data) #load zip data as dataframe
pd.set_option('display.max_columns',None) #show all columns
zipdf.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     91982         1       77494        zip        TX    TX      Katy
# 1     61148         2        8701        zip        NJ    NJ  Lakewood
# 2     91940         3       77449        zip        TX    TX      Katy
# 3     62080         4       11368        zip        NY    NY  New York
# 4     91733         5       77084        zip        TX    TX   Houston
#
#                                    Metro        CountyName     1996-02-29  \
# 0   Houston-The Woodlands-Sugar Land, TX  Fort Bend County  174725.633029
# 1  New York-Newark-Jersey City, NY-NJ-PA      Ocean County  142758.982237
# 2   Houston-The Woodlands-Sugar Land, TX     Harris County  101043.651448
# 3  New York-Newark-Jersey City, NY-NJ-PA     Queens County  199178.528054
# 4   Houston-The Woodlands-Sugar Land, TX     Harris County   95468.094264
#
#       1996-03-31     1996-04-30     1996-05-31     1996-06-30     1996-07-31  \
# ...

# %%
zipdf = zipdf.fillna(0)
zipdf = zipdf.loc[(zipdf !=0).any(axis=1)] #remove rows with no information
zipdf = zipdf.drop('StateName', axis=1) #drop duplicate row
zipdf.rename(columns={'CountyName': 'County','RegionName':'Zipcode'}, inplace=True)
#rename columns

# %%
zipdf.describe() #descriptive statistics
# Out:
#             RegionID      SizeRank       Zipcode    1996-02-29    1996-03-31  \
# count   29123.000000  29123.000000  29123.000000  2.912300e+04  2.912300e+04
# mean    80620.149985  15142.507091  48911.868077  6.044136e+04  6.097344e+04
# std     27267.483301   9161.760920  27228.852992  8.851055e+04  9.071025e+04
# min     58196.000000      1.000000   1001.000000  0.000000e+00  0.000000e+00
# 25%     69033.500000   7363.500000  26420.000000  0.000000e+00  0.000000e+00
# 50%     79347.000000  14778.000000  48647.000000  0.000000e+00  0.000000e+00
# 75%     88784.500000  22405.000000  70603.000000  9.955552e+04  1.001061e+05
# max    808739.000000  39992.000000  99929.000000  2.753878e+06  2.868423e+06
#
#          1996-04-30    1996-05-31    1996-06-30    1996-07-31    1996-08-31  \
# count  2.912300e+04  2.912300e+04  2.912300e+04  2.912300e+04  2.912300e+04
# mean   6.130232e+04  6.180150e+04  6.275811e+04  6.342476e+04  6.379894e+04
# ...

# %%
metrodf = zipdf.loc[:, 'Metro':'2023-12-31'] #select a range of columns (metro to end column)
metrodf.head()
# Out:
#                                    Metro            County     1996-02-29  \
# 0   Houston-The Woodlands-Sugar Land, TX  Fort Bend County  174725.633029
# 1  New York-Newark-Jersey City, NY-NJ-PA      Ocean County  142758.982237
# 2   Houston-The Woodlands-Sugar Land, TX     Harris County  101043.651448
# 3  New York-Newark-Jersey City, NY-NJ-PA     Queens County  199178.528054
# 4   Houston-The Woodlands-Sugar Land, TX     Harris County   95468.094264
#
#       1996-03-31     1996-04-30     1996-05-31     1996-06-30     1996-07-31  \
# 0  174833.374806  173773.511696  177019.817355  177927.141743  182698.529032
# 1  141784.949042  141198.937351  141175.168724  140730.097835  141415.597910
# 2  101039.701864  101672.626482  101505.406068  101487.173072  101338.816867
# 3  200561.738371  202521.635319  202600.557398  202549.607010  201681.482052
# 4   95708.573963   96226.953831   96466.578474   96551.450124   96264.043155
#
# ...

# %%
arkmetro = ['Hot Springs, AR', 'Little Rock-North Little Rock-Conway, AR', 'Fayetteville-Springdale-Rogers, AR', 'Searcy, AR']
filterdf = metrodf[metrodf['Metro'].isin(arkmetro)] #return metros with arkmetro variables 
filterdf
# Out:
#                                           Metro             County  \
# 715          Fayetteville-Springdale-Rogers, AR  Washington County
# 1005   Little Rock-North Little Rock-Conway, AR    Faulkner County
# 1017         Fayetteville-Springdale-Rogers, AR  Washington County
# 1149                            Hot Springs, AR     Garland County
# 1372         Fayetteville-Springdale-Rogers, AR  Washington County
# ...                                         ...                ...
# 23827        Fayetteville-Springdale-Rogers, AR     Madison County
# 24029                                Searcy, AR       White County
# 24620  Little Rock-North Little Rock-Conway, AR       Grant County
# 25701  Little Rock-North Little Rock-Conway, AR       Perry County
# 28420                                Searcy, AR       White County
#
#           1996-02-29     1996-03-31     1996-04-30     1996-05-31  \
# 715     98198.271545   98588.750986   98867.271662   99656.540883
# ...

# %%
dates = [col for col in filterdf.columns if '-' in col] #turn columns with - to date variable

dates = [col for col in dates if pd.to_datetime(col).year >= 1997] #turn col into datetime and return all cols from 1997
filtered_df = filterdf[['Metro']+ dates] #add dates and metro column to new filtered df
filtered_df
# Out:
#                                           Metro     1997-01-31     1997-02-28  \
# 715          Fayetteville-Springdale-Rogers, AR  101065.647174  101104.515395
# 1005   Little Rock-North Little Rock-Conway, AR  116839.354916  117784.923671
# 1017         Fayetteville-Springdale-Rogers, AR  103356.729164  103194.086590
# 1149                            Hot Springs, AR   80006.067240   81461.234162
# 1372         Fayetteville-Springdale-Rogers, AR  121152.633548  121169.178648
# ...                                         ...            ...            ...
# 23827        Fayetteville-Springdale-Rogers, AR       0.000000       0.000000
# 24029                                Searcy, AR   63110.780002   63260.900078
# 24620  Little Rock-North Little Rock-Conway, AR       0.000000       0.000000
# 25701  Little Rock-North Little Rock-Conway, AR       0.000000       0.000000
# 28420                                Searcy, AR   73181.604776   72871.786535
#
# ...

# %%
metro_averages = filtered_df.groupby('Metro')[dates].mean()  #return mean of df with and groupby metro
metro_averages
# Out:
#                                             1997-01-31    1997-02-28  \
# Metro
# Fayetteville-Springdale-Rogers, AR        91097.582517  90985.554733
# Hot Springs, AR                           67565.692642  68706.604109
# Little Rock-North Little Rock-Conway, AR  89017.392911  88992.285137
# Searcy, AR                                76124.304568  76094.173162
#
#                                             1997-03-31    1997-04-30  \
# Metro
# Fayetteville-Springdale-Rogers, AR        91791.883636  92961.606871
# Hot Springs, AR                           68330.291044  68329.772679
# Little Rock-North Little Rock-Conway, AR  89241.926144  89760.419552
# Searcy, AR                                76609.738530  76750.269859
#
#                                             1997-05-31    1997-06-30  \
# Metro
# Fayetteville-Springdale-Rogers, AR        93583.868573  93386.885015
# Hot Springs, AR                           68847.818223  68980.473256
# ...

# %%
metro_averages = metro_averages.T #flip columns and rows
metro_averages
# Out:
# Metro       Fayetteville-Springdale-Rogers, AR  Hot Springs, AR  \
# 1997-01-31                        91097.582517     67565.692642
# 1997-02-28                        90985.554733     68706.604109
# 1997-03-31                        91791.883636     68330.291044
# 1997-04-30                        92961.606871     68329.772679
# 1997-05-31                        93583.868573     68847.818223
# ...                                        ...              ...
# 2023-08-31                       332241.080512    242159.231217
# 2023-09-30                       333523.552953    242003.933881
# 2023-10-31                       333266.148885    240938.595423
# 2023-11-30                       332358.385895    239713.883120
# 2023-12-31                       330217.821026    237760.148719
#
# Metro       Little Rock-North Little Rock-Conway, AR     Searcy, AR
# 1997-01-31                              89017.392911   76124.304568
# ...

# %%
ax = metro_averages.plot() #plot all all metro averages 
plt.xticks(rotation=45, ha='right') #fix x axis label spacing
# Out:
# (array([-50.,   0.,  50., 100., 150., 200., 250., 300., 350.]),
#  [Text(-50.0, 0, '2019-11-30'),
#   Text(0.0, 0, '1997-01-31'),
#   Text(50.0, 0, '2001-03-31'),
#   Text(100.0, 0, '2005-05-31'),
#   Text(150.0, 0, '2009-07-31'),
#   Text(200.0, 0, '2013-09-30'),
#   Text(250.0, 0, '2017-11-30'),
#   Text(300.0, 0, '2022-01-31'),
#   Text(350.0, 0, '')])

# %% [markdown]
# In the code above, Fayetville has the most consistent upward growth of housing values throughout the entire dataset from 1997 to 2023. Searcy has the lowest on average.

# %%
dates2 = [col for col in zipdf.columns if '-' in col]

dates2 = [col for col in dates2 if pd.to_datetime(col).year == 2018] 
filtered_2018 = filterdf[['Metro']+ dates2] #add dates to new filtered 2018 with metro col
filtered_2018
# Out:
#                                           Metro     2018-01-31     2018-02-28  \
# 715          Fayetteville-Springdale-Rogers, AR  174184.229804  174001.304001
# 1005   Little Rock-North Little Rock-Conway, AR  193130.244733  193168.044373
# 1017         Fayetteville-Springdale-Rogers, AR  239761.032609  238649.420596
# 1149                            Hot Springs, AR  181431.933930  180368.867032
# 1372         Fayetteville-Springdale-Rogers, AR  215490.540975  215122.321772
# ...                                         ...            ...            ...
# 23827        Fayetteville-Springdale-Rogers, AR  137682.957525  137201.246847
# 24029                                Searcy, AR  113306.399300  112493.926701
# 24620  Little Rock-North Little Rock-Conway, AR  136475.416631  137132.083720
# 25701  Little Rock-North Little Rock-Conway, AR  103703.954038  102747.051068
# 28420                                Searcy, AR   89375.320431   88982.680366
#
# ...

# %%
averages_2018 = filtered_2018.groupby('Metro')[dates2].mean() #group the 2018 averages by metro
averages_2018
# Out:
#                                              2018-01-31     2018-02-28  \
# Metro
# Fayetteville-Springdale-Rogers, AR        190992.340307  190585.829188
# Hot Springs, AR                           147977.437279  146832.791756
# Little Rock-North Little Rock-Conway, AR  168430.871256  167371.187347
# Searcy, AR                                130020.400414  128435.804770
#
#                                              2018-03-31     2018-04-30  \
# Metro
# Fayetteville-Springdale-Rogers, AR        192322.917834  194034.733636
# Hot Springs, AR                           148422.714179  149725.397900
# Little Rock-North Little Rock-Conway, AR  168448.933600  168926.281418
# Searcy, AR                                130182.648141  130476.321155
#
#                                              2018-05-31     2018-06-30  \
# Metro
# Fayetteville-Springdale-Rogers, AR        195656.437370  196589.125419
# Hot Springs, AR                           151121.875135  152242.072775
# ...

# %%
averages_2018 = averages_2018.T #flip columns and rows
averages_2018
# Out:
# Metro       Fayetteville-Springdale-Rogers, AR  Hot Springs, AR  \
# 2018-01-31                       190992.340307    147977.437279
# 2018-02-28                       190585.829188    146832.791756
# 2018-03-31                       192322.917834    148422.714179
# 2018-04-30                       194034.733636    149725.397900
# 2018-05-31                       195656.437370    151121.875135
# 2018-06-30                       196589.125419    152242.072775
# 2018-07-31                       198263.894608    154397.171094
# 2018-08-31                       198606.012207    155173.021845
# 2018-09-30                       198361.689704    155643.664306
# 2018-10-31                       197869.890544    155755.009849
# 2018-11-30                       197635.418666    155694.290513
# 2018-12-31                       198259.436213    155536.955814
#
# Metro       Little Rock-North Little Rock-Conway, AR     Searcy, AR
# ...

# %%
ax = averages_2018.plot() #plot 2018 averages
plt.xticks(rotation=45, ha='right') #fix x axis label spacing
# Out:
# (array([-2.,  0.,  2.,  4.,  6.,  8., 10., 12.]),
#  [Text(-2.0, 0, '2018-11-30'),
#   Text(0.0, 0, '2018-01-31'),
#   Text(2.0, 0, '2018-03-31'),
#   Text(4.0, 0, '2018-05-31'),
#   Text(6.0, 0, '2018-07-31'),
#   Text(8.0, 0, '2018-09-30'),
#   Text(10.0, 0, '2018-11-30'),
#   Text(12.0, 0, '')])

# %%
averages_2018.plot(subplots=True, figsize=(10, 8), layout=(2, 2)) #generate subplots of 2018 averages 
plt.xticks(rotation=45, ha='right')
# Out:
# (array([-2.,  0.,  2.,  4.,  6.,  8., 10., 12.]),
#  [Text(-2.0, 0, '2018-11-30'),
#   Text(0.0, 0, '2018-01-31'),
#   Text(2.0, 0, '2018-03-31'),
#   Text(4.0, 0, '2018-05-31'),
#   Text(6.0, 0, '2018-07-31'),
#   Text(8.0, 0, '2018-09-30'),
#   Text(10.0, 0, '2018-11-30'),
#   Text(12.0, 0, '')])

# %% [markdown]
# According to the subplots, Fayetteville by far has the best housing values on averages across year 2018. It would be wise to invest in Fayetteville.

# %%
zips = zipdf.loc[:, 'Zipcode':'2023-12-31'] #select a range of columns (Zipcode to end column)
faymetro = ['Fayetteville-Springdale-Rogers, AR']
fayzips = zips[zips['Metro'].isin(faymetro)] #return metros with faymetro variables 
fayzips.head()
# Out:
#       Zipcode RegionType State          City  \
# 715     72764        zip    AR    Springdale
# 1017    72701        zip    AR  Fayetteville
# 1372    72762        zip    AR    Springdale
# 1568    72756        zip    AR        Rogers
# 1654    72712        zip    AR   Bentonville
#
#                                    Metro             County     1996-02-29  \
# 715   Fayetteville-Springdale-Rogers, AR  Washington County   98198.271545
# 1017  Fayetteville-Springdale-Rogers, AR  Washington County   99110.611927
# 1372  Fayetteville-Springdale-Rogers, AR  Washington County  116633.057542
# 1568  Fayetteville-Springdale-Rogers, AR      Benton County   83602.708189
# 1654  Fayetteville-Springdale-Rogers, AR      Benton County  138284.534748
#
#          1996-03-31     1996-04-30     1996-05-31     1996-06-30  \
# 715    98588.750986   98867.271662   99656.540883  100140.730425
# 1017   99852.259089  100279.603724  101206.932262  102345.347447
# ...

# %%
filtered_fay = fayzips[['Zipcode']+ dates] #add dates and metro column to new filtered df
filtered_fay
# Out:
#        Zipcode     1997-01-31     1997-02-28     1997-03-31     1997-04-30  \
# 715      72764  101065.647174  101104.515395  101732.633694  102743.449436
# 1017     72701  103356.729164  103194.086590  104193.762580  104987.739863
# 1372     72762  121152.633548  121169.178648  122252.736292  123261.912599
# 1568     72756   86462.120819   86160.983902   86559.272165   91982.321486
# 1654     72712  146075.767921  146365.437548  147452.235716  148779.725751
# 1658     72758  140696.825945  140515.191349  141537.005400  147227.268213
# 2891     72703  138780.870114  138891.139532  139945.405068  140825.084293
# 3648     72704  114202.052258  114266.658294  115107.002534  115807.283898
# 5347     72713  136506.490065  136837.439598  137910.700008  139360.477926
# 5472     72761   88253.233281   87995.995089   88784.232783   89646.788561
# 7393     72745   85503.728936   85437.468287   86022.744965   90423.483903
# ...

# %%
fay_averages = filtered_fay.groupby('Zipcode')[dates].mean()  #return mean of df with and groupby metro
fay_averages
# Out:
#             1997-01-31     1997-02-28     1997-03-31     1997-04-30  \
# Zipcode
# 72701    103356.729164  103194.086590  104193.762580  104987.739863
# 72703    138780.870114  138891.139532  139945.405068  140825.084293
# 72704    114202.052258  114266.658294  115107.002534  115807.283898
# 72712    146075.767921  146365.437548  147452.235716  148779.725751
# 72713    136506.490065  136837.439598  137910.700008  139360.477926
# 72714    100657.817785  100449.883215  101016.970803  102788.551037
# 72715    112816.671731  112232.452721  112627.250828  115789.367843
# 72717     54372.304472   54121.788286   54889.705127   56617.533128
# 72718    145094.826768  144372.699378  144643.145977  146207.857410
# 72719    109330.951487  109270.922284  109214.841011  109141.527055
# 72722     67470.314309   68182.779794   68947.823636   68121.072698
# 72727     76707.921078   76402.808860   77446.487550   78311.219150
# 72730     94393.161253   94368.301729   95221.253604   95592.619060
# ...

# %%
overall_avg_per_row = fay_averages.mean(axis=1)

print('Overall average for each row:')
print(overall_avg_per_row)
# Out:
# Overall average for each row:
# Zipcode
# 72701    202869.081765
# 72703    234281.025968
# 72704    193254.370176
# 72712    232841.717196
# 72713    232329.481538
# 72714    160719.310653
# 72715    171942.660157
# 72717    119384.599587
# 72718    254264.798752
# 72719    174180.555490
# 72722    126149.531535
# 72727    136919.233485
# 72730    168762.948944
# 72732    202194.144980
# 72734    135694.401317
# 72736    136604.506036
# 72738    179144.919212
# 72739    137888.057876
# 72740    120266.332451
# 72742    126306.613412
# 72744    125634.210467
# 72745    159143.988551
# 72751    149876.420696
# 72753    147977.712573
# 72756    157894.270858
# 72758    225040.509341
# 72761    144145.338739
# 72762    195286.215542
# 72764    158563.119722
# 72768     99279.501988
# 72769    189967.997003
# 72773    120985.403137
# 72774    152890.056937
# 72776     58555.771205
# 72959    130498.509562
# dtype: float64

# %%
sort_avgs =overall_avg_per_row.sort_values(ascending=False)
print(sort_avgs)
# Out:
# Zipcode
# 72718    254264.798752
# 72703    234281.025968
# 72712    232841.717196
# 72713    232329.481538
# 72758    225040.509341
# 72701    202869.081765
# 72732    202194.144980
# 72762    195286.215542
# 72704    193254.370176
# 72769    189967.997003
# 72738    179144.919212
# 72719    174180.555490
# 72715    171942.660157
# 72730    168762.948944
# 72714    160719.310653
# 72745    159143.988551
# 72764    158563.119722
# 72756    157894.270858
# 72774    152890.056937
# 72751    149876.420696
# 72753    147977.712573
# 72761    144145.338739
# 72739    137888.057876
# 72727    136919.233485
# 72736    136604.506036
# 72734    135694.401317
# 72959    130498.509562
# 72742    126306.613412
# 72722    126149.531535
# 72744    125634.210467
# 72773    120985.403137
# 72740    120266.332451
# 72717    119384.599587
# 72768     99279.501988
# 72776     58555.771205
# dtype: float64

# %% [markdown]
# These zipcodes have the highest averages for housing (72718, 72703, 72712) acorss the Fayetteville metro from 1997 to 2023. These codes provide the best investment opportunity for SREIT as they generate the highest housing values.

# %%
dates3 = [col for col in dates if pd.to_datetime(col).year <=2017] #return all cols equal or less than the year 2017
filtered_97= filterdf[['Metro']+dates3]
filtered_97
# Out:
#                                           Metro     1997-01-31     1997-02-28  \
# 715          Fayetteville-Springdale-Rogers, AR  101065.647174  101104.515395
# 1005   Little Rock-North Little Rock-Conway, AR  116839.354916  117784.923671
# 1017         Fayetteville-Springdale-Rogers, AR  103356.729164  103194.086590
# 1149                            Hot Springs, AR   80006.067240   81461.234162
# 1372         Fayetteville-Springdale-Rogers, AR  121152.633548  121169.178648
# ...                                         ...            ...            ...
# 23827        Fayetteville-Springdale-Rogers, AR       0.000000       0.000000
# 24029                                Searcy, AR   63110.780002   63260.900078
# 24620  Little Rock-North Little Rock-Conway, AR       0.000000       0.000000
# 25701  Little Rock-North Little Rock-Conway, AR       0.000000       0.000000
# 28420                                Searcy, AR   73181.604776   72871.786535
#
# ...

# %%
avgs9717 = filtered_97.groupby('Metro')[dates3].mean() #group 97 to 17 averages by metro
avgs9717
# Out:
#                                             1997-01-31    1997-02-28  \
# Metro
# Fayetteville-Springdale-Rogers, AR        91097.582517  90985.554733
# Hot Springs, AR                           67565.692642  68706.604109
# Little Rock-North Little Rock-Conway, AR  89017.392911  88992.285137
# Searcy, AR                                76124.304568  76094.173162
#
#                                             1997-03-31    1997-04-30  \
# Metro
# Fayetteville-Springdale-Rogers, AR        91791.883636  92961.606871
# Hot Springs, AR                           68330.291044  68329.772679
# Little Rock-North Little Rock-Conway, AR  89241.926144  89760.419552
# Searcy, AR                                76609.738530  76750.269859
#
#                                             1997-05-31    1997-06-30  \
# Metro
# Fayetteville-Springdale-Rogers, AR        93583.868573  93386.885015
# Hot Springs, AR                           68847.818223  68980.473256
# ...

# %%
avgs9717 = avgs9717.T #flip columns and rows
avgs9717
# Out:
# Metro       Fayetteville-Springdale-Rogers, AR  Hot Springs, AR  \
# 1997-01-31                        91097.582517     67565.692642
# 1997-02-28                        90985.554733     68706.604109
# 1997-03-31                        91791.883636     68330.291044
# 1997-04-30                        92961.606871     68329.772679
# 1997-05-31                        93583.868573     68847.818223
# ...                                        ...              ...
# 2017-08-31                       189221.485402    147235.006757
# 2017-09-30                       190210.282581    147529.920386
# 2017-10-31                       190972.564837    147983.245864
# 2017-11-30                       191302.332969    147735.699116
# 2017-12-31                       191598.607136    147619.638571
#
# Metro       Little Rock-North Little Rock-Conway, AR     Searcy, AR
# 1997-01-31                              89017.392911   76124.304568
# ...

# %%
ax = avgs9717.plot() #plot 97 to 17 averages
plt.xticks(rotation=45, ha='right')
# Out:
# (array([-50.,   0.,  50., 100., 150., 200., 250., 300.]),
#  [Text(-50.0, 0, '2013-11-30'),
#   Text(0.0, 0, '1997-01-31'),
#   Text(50.0, 0, '2001-03-31'),
#   Text(100.0, 0, '2005-05-31'),
#   Text(150.0, 0, '2009-07-31'),
#   Text(200.0, 0, '2013-09-30'),
#   Text(250.0, 0, '2017-11-30'),
#   Text(300.0, 0, '')])

# %%
avgs9717.plot(subplots=True, figsize=(10, 8), layout=(2, 2))
plt.xticks(rotation=45, ha='right')
# Out:
# (array([-50.,   0.,  50., 100., 150., 200., 250., 300.]),
#  [Text(-50.0, 0, '2013-11-30'),
#   Text(0.0, 0, '1997-01-31'),
#   Text(50.0, 0, '2001-03-31'),
#   Text(100.0, 0, '2005-05-31'),
#   Text(150.0, 0, '2009-07-31'),
#   Text(200.0, 0, '2013-09-30'),
#   Text(250.0, 0, '2017-11-30'),
#   Text(300.0, 0, '')])

# %%
# EXPLORE - IS OUR TIME SERIES STATIONARY OR NOT?

result = adfuller(avgs9717['Fayetteville-Springdale-Rogers, AR'], autolag='AIC')

print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -1.284358
# p-value: 0.636298
# Critical Values:
# 	1%: -3.458
# 	5%: -2.874
# 	10%: -2.573

# %%
# create a differenced series
def difference(dataset, interval=1):
	diff = list()
	for i in range(interval, len(dataset)):
		value = dataset[i] - dataset[i - interval]
		diff.append(value)
	return pd.Series(diff)


X = avgs9717['Fayetteville-Springdale-Rogers, AR']
X = X.astype('float32')
# difference data
weeks_in_year = 52
stationary = difference(X, weeks_in_year)
stationary.index = avgs9717.index[weeks_in_year:]
# check if stationary
result = adfuller(stationary)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))

# plot
stationary.plot()
# Out:
# ADF Statistic: -4.066181
# p-value: 0.001101
# Critical Values:
# 	1%: -3.466
# 	5%: -2.877
# 	10%: -2.575
# C:\Users\tofaj\AppData\Local\Temp\ipykernel_12856\2460776204.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   value = dataset[i] - dataset[i - interval]
# <Axes: >

# %% [markdown]
# Series is stationary

# %%
def inverse_difference(history, yhat, interval=1):
    return yhat + history[-interval]
#invert difference value

# %%
series = stationary

plot_acf(series) #Plot autoregressive of stationary series
plot_pacf(series) #plot partial autocorrelation of stationary series
# Out:
# C:\Users\tofaj\Downloads\New folder\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
plot_pacf(series)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX 
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima_model import ARIMAResults
from math import sqrt
from pandas import DataFrame
# invert differenced value
def inverse_difference(history, yhat, interval=1):
    return yhat + history[-interval]
# load data
series = avgs9717['Fayetteville-Springdale-Rogers, AR']
# prepare data
X = series.values
X = X.astype('float32')
train_size = int(len(X) * 0.50)
train, test = X[0:train_size], X[train_size:]
# walk-forward validation
history = [x for x in train]
predictions = list()
bias = -120.713087
for i in range(len(test)):
    # difference data
    weeks_in_year = 52
    diff = difference(history, weeks_in_year)
    # predict
    model = SARIMAX(diff, order=(2,1,0))
    model_fit = model.fit(trend='nc', disp=0)
    yhat = model_fit.forecast()
    yhat = bias + inverse_difference(history, yhat, weeks_in_year)
    predictions.append(yhat)
    # observation
    obs = test[i]
    history.append(obs)
print('Predicted=%.3f, Expected=%3.f' % (yhat, obs))
# report performance
mse = mean_squared_error(test, predictions)
rmse = sqrt(mse)
print('RMSE: %.3f' % rmse)
# Out:
# C:\Users\tofaj\Downloads\New folder\lib\site-packages\statsmodels\base\optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method lbfgs is: m, pgtol, factr, maxfun, epsilon, approx_grad, bounds, loglike_and_score. The list of unsupported keyword arguments passed include: trend. After release 0.14, this will raise.
#   warnings.warn(
# C:\Users\tofaj\Downloads\New folder\lib\site-packages\statsmodels\base\optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method lbfgs is: m, pgtol, factr, maxfun, epsilon, approx_grad, bounds, loglike_and_score. The list of unsupported keyword arguments passed include: trend. After release 0.14, this will raise.
#   warnings.warn(
# ...

# %% [markdown]
# For Fayetteville
# Predicted=191676.333, Expected=191599
# RMSE: 1383.532

# %%
# load data
series = avgs9717['Hot Springs, AR']
# prepare data
X = series.values
X = X.astype('float32')
train_size = int(len(X) * 0.50)
train, test = X[0:train_size], X[train_size:]
# walk-forward validation
history = [x for x in train]
predictions = list()
bias = -120.713087
for i in range(len(test)):
    # difference data
    weeks_in_year = 52
    diff = difference(history, weeks_in_year)
    # predict
    model = SARIMAX(diff, order=(2,1,0))
    model_fit = model.fit(trend='nc', disp=0)
    yhat = model_fit.forecast()
    yhat = bias + inverse_difference(history, yhat, weeks_in_year)
    predictions.append(yhat)
    # observation
    obs = test[i]
    history.append(obs)
print('Predicted=%.3f, Expected=%3.f' % (yhat, obs))
# report performance
mse = mean_squared_error(test, predictions)
rmse = sqrt(mse)
print('RMSE: %.3f' % rmse)
# Out:
# C:\Users\tofaj\Downloads\New folder\lib\site-packages\statsmodels\base\optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method lbfgs is: m, pgtol, factr, maxfun, epsilon, approx_grad, bounds, loglike_and_score. The list of unsupported keyword arguments passed include: trend. After release 0.14, this will raise.
#   warnings.warn(
# C:\Users\tofaj\Downloads\New folder\lib\site-packages\statsmodels\base\optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method lbfgs is: m, pgtol, factr, maxfun, epsilon, approx_grad, bounds, loglike_and_score. The list of unsupported keyword arguments passed include: trend. After release 0.14, this will raise.
#   warnings.warn(
# ...

# %% [markdown]
# Hot Springs
# Predicted=148215.739, Expected=147620
# RMSE: 3863.520

# %%
# load data
series = avgs9717['Little Rock-North Little Rock-Conway, AR']
# prepare data
X = series.values
X = X.astype('float32')
train_size = int(len(X) * 0.50)
train, test = X[0:train_size], X[train_size:]
# walk-forward validation
history = [x for x in train]
predictions = list()
bias = -120.713087
for i in range(len(test)):
    # difference data
    weeks_in_year = 52
    diff = difference(history, weeks_in_year)
    # predict
    model = SARIMAX(diff, order=(2,1,0))
    model_fit = model.fit(trend='nc', disp=0)
    yhat = model_fit.forecast()
    yhat = bias + inverse_difference(history, yhat, weeks_in_year)
    predictions.append(yhat)
    # observation
    obs = test[i]
    history.append(obs)
print('Predicted=%.3f, Expected=%3.f' % (yhat, obs))
# report performance
mse = mean_squared_error(test, predictions)
rmse = sqrt(mse)
print('RMSE: %.3f' % rmse)
# Out:
# C:\Users\tofaj\Downloads\New folder\lib\site-packages\statsmodels\base\optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method lbfgs is: m, pgtol, factr, maxfun, epsilon, approx_grad, bounds, loglike_and_score. The list of unsupported keyword arguments passed include: trend. After release 0.14, this will raise.
#   warnings.warn(
# C:\Users\tofaj\Downloads\New folder\lib\site-packages\statsmodels\base\optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method lbfgs is: m, pgtol, factr, maxfun, epsilon, approx_grad, bounds, loglike_and_score. The list of unsupported keyword arguments passed include: trend. After release 0.14, this will raise.
#   warnings.warn(
# ...

# %% [markdown]
# Little Rock
# Predicted=169785.077, Expected=169211
# RMSE: 2297.896

# %%
# load data
series = avgs9717['Searcy, AR']
# prepare data
X = series.values
X = X.astype('float32')
train_size = int(len(X) * 0.50)
train, test = X[0:train_size], X[train_size:]
# walk-forward validation
history = [x for x in train]
predictions = list()
bias = -120.713087
for i in range(len(test)):
    # difference data
    weeks_in_year = 52
    diff = difference(history, weeks_in_year)
    # predict
    model = SARIMAX(diff, order=(2,1,0))
    model_fit = model.fit(trend='nc', disp=0)
    yhat = model_fit.forecast()
    yhat = bias + inverse_difference(history, yhat, weeks_in_year)
    predictions.append(yhat)
    # observation
    obs = test[i]
    history.append(obs)
print('Predicted=%.3f, Expected=%3.f' % (yhat, obs))
# report performance
mse = mean_squared_error(test, predictions)
rmse = sqrt(mse)
print('RMSE: %.3f' % rmse)
# Out:
# C:\Users\tofaj\Downloads\New folder\lib\site-packages\statsmodels\base\optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method lbfgs is: m, pgtol, factr, maxfun, epsilon, approx_grad, bounds, loglike_and_score. The list of unsupported keyword arguments passed include: trend. After release 0.14, this will raise.
#   warnings.warn(
# C:\Users\tofaj\Downloads\New folder\lib\site-packages\statsmodels\base\optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method lbfgs is: m, pgtol, factr, maxfun, epsilon, approx_grad, bounds, loglike_and_score. The list of unsupported keyword arguments passed include: trend. After release 0.14, this will raise.
#   warnings.warn(
# ...

# %% [markdown]
# Searcy
# Predicted=131891.314, Expected=130921
# RMSE: 2579.100

# %% [markdown]
# For the down sampling decision process, scrubbing the data, the Arkansas metro were the areas of focus. Then after conducting an analysis to identify trends within the areas across the years, Fayetteville seemed like it generated the highest housing values. Since the trend is higher than other metros, the zipcodes within Fayetteville were then analyzed it predicts the best investment opportunity. An Arima model was also used to forecast future housing values within the respective areas.
